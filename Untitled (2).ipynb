# %%
pip install gspread oauth2client
# Out:
# ...
#
# ...

# %%
pip install gspread google-auth
# Out:
# ...
#
# ...

# %%
import gspread 
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd

# %%
scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name("b2b-sales-analytics-878c5c7e1456.json", scope)
client = gspread.authorize(creds)

# Accounts 
sheet_1 = client.open("B2B-Sales-Analytics-with-SQL-Power-BI").worksheet('accounts')
data1 = sheet_1.get_all_records()
accounts = pd.DataFrame(data1)

# data_dictionary
sheet_2 = client.open("B2B-Sales-Analytics-with-SQL-Power-BI").worksheet('data_dictionary')
data2 = sheet_2.get_all_records()
data_dictionary = pd.DataFrame(data2)

# products 
sheet_3 = client.open("B2B-Sales-Analytics-with-SQL-Power-BI").worksheet('products')
data3 = sheet_3.get_all_records()
products = pd.DataFrame(data3)

# sales_pipeline
sheet_4 = client.open("B2B-Sales-Analytics-with-SQL-Power-BI").worksheet('sales_pipeline')
data4 = sheet_4.get_all_records()
sales_pipeline = pd.DataFrame(data4)

# sales_teams 
sheet_5 = client.open("B2B-Sales-Analytics-with-SQL-Power-BI").worksheet('sales_teams')
data5 = sheet_5.get_all_records()
sales_teams = pd.DataFrame(data5)

# %%
accounts.head()
# Out:
#             account     sector  year_established  revenue  employees  \
# 0  Acme Corporation  technolgy              1996  1100.04       2822
# 1        Betasoloin    medical              1999   251.41        495
# 2          Betatech    medical              1986   647.18       1185
# 3        Bioholding    medical              2012   587.34       1356
# 4           Bioplex    medical              1991   326.82       1016
#
#   office_location subsidiary_of
# 0   United States
# 1   United States
# 2           Kenya
# 3      Philipines
# 4   United States

# %%
import numpy as np
import pandas as pd 
#import seaborn as sns 
#import matplotlib.pyplot as plt

# %%
accounts.head()
# Out:
#             account     sector  year_established  revenue  employees  \
# 0  Acme Corporation  technolgy              1996  1100.04       2822
# 1        Betasoloin    medical              1999   251.41        495
# 2          Betatech    medical              1986   647.18       1185
# 3        Bioholding    medical              2012   587.34       1356
# 4           Bioplex    medical              1991   326.82       1016
#
#   office_location subsidiary_of
# 0   United States
# 1   United States
# 2           Kenya
# 3      Philipines
# 4   United States

# %%
data_dictionary.head()
# Out:
#       Table             Field                          Description
# 0  accounts           account                         Company name
# 1  accounts            sector                             Industry
# 2  accounts  year_established                     Year Established
# 3  accounts           revenue  Annual revenue (in millions of USD)
# 4  accounts         employees                  Number of employees

# %%
products.head()
# Out:
#         product series  sales_price
# 0     GTX Basic    GTX          550
# 1       GTX Pro    GTX         4821
# 2    MG Special     MG           55
# 3   MG Advanced     MG         3393
# 4  GTX Plus Pro    GTX         5482

# %%
sales_pipeline.head()
# Out:
#   opportunity_id      sales_agent         product  account deal_stage  \
# 0       1C1I7A6R      Moses Frase  GTX Plus Basic  Cancity        Won
# 1       Z063OYW0  Darcel Schlecht          GTXPro    Isdom        Won
# 2       EC4QE1BX  Darcel Schlecht      MG Special  Cancity        Won
# 3       MV1LWRNH      Moses Frase       GTX Basic  Codehow        Won
# 4       PE84CX4O        Zane Levy       GTX Basic   Hatfan        Won
#
#   engage_date  close_date close_value
# 0  2016-10-20  2017-03-01        1054
# 1  2016-10-25  2017-03-11        4514
# 2  2016-10-25  2017-03-07          50
# 3  2016-10-25  2017-03-09         588
# 4  2016-10-25  2017-03-02         517

# %%
sales_teams.head()
# Out:
#          sales_agent           manager regional_office
# 0      Anna Snelling  Dustin Brinkmann         Central
# 1     Cecily Lampkin  Dustin Brinkmann         Central
# 2  Versie Hillebrand  Dustin Brinkmann         Central
# 3    Lajuana Vencill  Dustin Brinkmann         Central
# 4        Moses Frase  Dustin Brinkmann         Central

# %%
# Accounts  

## Dropping the subsidiary_of since it has more than 60 %  blank data 
accounts = accounts.drop("subsidiary_of",axis=1)

# %%
accounts.head()
# Out:
#             account     sector  year_established  revenue  employees  \
# 0  Acme Corporation  technolgy              1996  1100.04       2822
# 1        Betasoloin    medical              1999   251.41        495
# 2          Betatech    medical              1986   647.18       1185
# 3        Bioholding    medical              2012   587.34       1356
# 4           Bioplex    medical              1991   326.82       1016
#
#   office_location
# 0   United States
# 1   United States
# 2           Kenya
# 3      Philipines
# 4   United States

# %%
# sales_pipeline
sales_pipeline.head(20)
# Out:
#    opportunity_id        sales_agent         product  \
# 0        1C1I7A6R        Moses Frase  GTX Plus Basic
# 1        Z063OYW0    Darcel Schlecht          GTXPro
# 2        EC4QE1BX    Darcel Schlecht      MG Special
# 3        MV1LWRNH        Moses Frase       GTX Basic
# 4        PE84CX4O          Zane Levy       GTX Basic
# 5        ZNBS69V1      Anna Snelling      MG Special
# 6        9ME3374G     Vicki Laflamme      MG Special
# 7        7GN8Q4LL     Markita Hansen       GTX Basic
# 8        OLK9LKZB    Niesha Huffines  GTX Plus Basic
# 9        HAXMC4IX     James Ascencio     MG Advanced
# 10       NL3JZH1Z      Anna Snelling      MG Special
# 11       KWVA7VR1   Gladys Colclough          GTXPro
# 12       S8DX3XOU     James Ascencio    GTX Plus Pro
# 13       ENB2XD8G    Maureen Marcano    GTX Plus Pro
# 14       09YE9QOV      Hayden Neloms     MG Advanced
# 15       3F5MZNEH    Rosalina Dieter      MG Special
# 16       M6WEJXC0    Rosalina Dieter     MG Advanced
# ...

# %%
sales_pipeline.isnull().sum()
# Out:
# opportunity_id    0
# sales_agent       0
# product           0
# account           0
# deal_stage        0
# engage_date       0
# close_date        0
# close_value       0
# dtype: int64

# %%
# Dropping null values from accounts data, as rows without company information lack significance.
sales_pipeline.replace("", pd.NA, inplace=True)
sales_pipeline.isnull().sum()
# Out:
# opportunity_id       0
# sales_agent          0
# product              0
# account           1425
# deal_stage           0
# engage_date        500
# close_date        2089
# close_value       2089
# dtype: int64

# %%
sales_pipeline = sales_pipeline.dropna(subset=['account'])
sales_pipeline.isnull().sum()
# Out:
# opportunity_id      0
# sales_agent         0
# product             0
# account             0
# deal_stage          0
# engage_date       163
# close_date        664
# close_value       664
# dtype: int64

# %%
# Accounts 
print(accounts.head())

# data_dictionary
print(data_dictionary.head())

# products 
print(products.head())

# sales_pipeline
print(sales_pipeline.head())

# sales_teams 
print(sales_teams.head())
# Out:
#             account     sector  year_established  revenue  employees  \
# 0  Acme Corporation  technolgy              1996  1100.04       2822
# 1        Betasoloin    medical              1999   251.41        495
# 2          Betatech    medical              1986   647.18       1185
# 3        Bioholding    medical              2012   587.34       1356
# 4           Bioplex    medical              1991   326.82       1016
#
#   office_location
# 0   United States
# 1   United States
# 2           Kenya
# 3      Philipines
# 4   United States
#       Table             Field                          Description
# 0  accounts           account                         Company name
# 1  accounts            sector                             Industry
# 2  accounts  year_established                     Year Established
# 3  accounts           revenue  Annual revenue (in millions of USD)
# 4  accounts         employees                  Number of employees
# ...

# %% [markdown]
# ## Export CSV files to SQL server

# %%
pip install sqlalchemy pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
# change the /Ashish:Ashu#123 as USER:password of sql data base
engine = create_engine('mysql+pymysql://new_user:new_user#123@localhost/b2b')

# %%
#Import each DataFrame to MySQL   
accounts.to_sql('accounts', con=engine, if_exists='replace', index=False)
data_dictionary.to_sql('data_dictionary', con=engine, if_exists='replace', index=False)
products.to_sql('products', con=engine, if_exists='replace', index=False)
sales_pipeline.to_sql('sales_pipeline', con=engine, if_exists='replace', index=False)
sales_teams.to_sql('sales_teams', con=engine, if_exists='replace', index=False)

print("All data imported successfully!")
# Out:
# All data imported successfully!
